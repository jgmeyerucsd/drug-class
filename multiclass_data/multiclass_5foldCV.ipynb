# %% [markdown]
# ## Multi-label prediction with All drugs in the 12 MeSH classes

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.datasets import Config
import pandas as pd
import numpy as np
from fastai.vision.data import Image
from functools import partial
import torch
from fastai.metrics import *
from fastai import utils
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, matthews_corrcoef, auc
from sklearn.metrics import balanced_accuracy_score, accuracy_score, average_precision_score
from sklearn.preprocessing import OneHotEncoder, LabelBinarizer, MultiLabelBinarizer, label_binarize

# %%
torch.cuda.set_device(1)   ### use first GPU if you have many
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Getting the data

# %%
PATH = '/home/jgmeyer2/drugclass/multiclass_data/'

# %% [markdown]
# ## Multiclassification

# %%
df = pd.read_csv(f'{PATH}all_chem_df.csv')
#df.drop('', axis=1)
df.head()
# Out:
#   image_name                             tags  \
# 0     pics/0                     dermatologic
# 1     pics/1                    antiinfective
# 2     pics/2                    antiinfective
# 3     pics/3                   antineoplastic
# 4     pics/4  antiinfective respiratorysystem
#
#                                               smiles  \
# 0                         CC(=O)NC1C(O)OC(CO)C(O)C1O
# 1  CCC[C@@]1(CCc2ccccc2)CC(O)=C([C@H](CC)c2cccc(N...
# 2  CCCCC(C)C(=O)OC1C(C)C(CC)OC2(CC3CC(C/C=C(\C)CC...
# 3  COc1cc2c(c(OC)c1OC)-c1c(cc3c(c1OC)OCO3)C[C@H](...
# 4                         CC(=O)N[C@@H](CS)C(=O)[O-]
#
#                                      Col3
# 0                        ['dermatologic']
# 1                       ['antiinfective']
# 2                       ['antiinfective']
# 3                      ['antineoplastic']
# 4  ['antiinfective', 'respiratorysystem']

# %%
# print unique labels
print(len(set([x.split(' ')[0] for x in df['tags']])))
set([x.split(' ')[0] for x in df['tags']])
# Out:
# 12
# {'antiinfective',
#  'antiinflammatory',
#  'antineoplastic',
#  'cardio',
#  'cns',
#  'dermatologic',
#  'gastrointestinal',
#  'hematologic',
#  'lipidregulating',
#  'reproductivecontrol',
#  'respiratorysystem',
#  'urological'}

# %% [markdown]
# To put this in a `DataBunch` while using the [data block API](https://docs.fast.ai/data_block.html), we then need to using `ImageList` (and not `ImageDataBunch`). This will make sure the model created has the proper loss function to deal with the multiple classes.

# %%
tfms = get_transforms(do_flip=True, flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0)

# %%
def get_val_idx_fromfile(validx_csv):
    validx_df =pd.read_csv(validx_csv, header=None)
    return validx_df[0].tolist()

# %%
vidx = get_val_idx_fromfile('multilabel_iter5fold_4.csv')

# %%
len(vidx)
# Out:
# 1670

# %%
np.random.seed(42)
src = (ImageItemList.from_csv(PATH, 'all_chem_df.csv', folder='', suffix='.png')
       .split_by_idx(vidx)
       .label_from_df(label_delim=' '))

# %%
data = (src.transform(tfms, size=256)
        .databunch().normalize(imagenet_stats))

# %%
#data.show_batch(rows=3, figsize=(150,150))

# %%
data.batch_size = 40
data.batch_size
# Out:
# 40

# %%
arch = models.resnet50

# %%
acc_50 = partial(accuracy_thresh, thresh=0.5, sigmoid=False)
fs = partial(fbeta, thresh=0.5, sigmoid=False)
learn = create_cnn(data, arch, metrics=[acc_50, fs], ps=0.4)

# %%
np.random.seed(42)
acc_50 = partial(accuracy_thresh, thresh=0.5, sigmoid=False)
fs = partial(fbeta, thresh=0.5, sigmoid=False)
act = []
fbe = []
roc = []
avp = []
for rep in range(0, 5):
    print(rep)
    vidx = get_val_idx_fromfile('multilabel_iter5fold_'+str(rep)+'.csv')
    data = (ImageItemList.from_csv(PATH, 'all_chem_df.csv', folder='', suffix='.png')
            .split_by_idx(vidx).label_from_df(label_delim=' ')
            .transform(tfms, size=256)
            .databunch().normalize(imagenet_stats))
    data.batch_size = 40
    data.num_workers = 1
    arch = models.resnet50
    learn = create_cnn(data, arch, metrics=[acc_50, fs], ps=0.4)
    learn.unfreeze()
    learn.fit_one_cycle(127, slice(1e-4, 1e-2))
    probs, y = learn.TTA()
    act.append(accuracy_thresh(probs, y, thresh= 0.5, sigmoid=False).item())
    fbe.append(fbeta(probs, y, thresh = 0.5, sigmoid=False).item())
    roc.append(roc_auc_score(y, probs, average="weighted"))
    avp.append(average_precision_score(y, probs, average="weighted"))
# Out:
# Total time: 00:58 <p>

# %%
print('acc thresholded mean '+str(np.mean(act))+'+/-'+str(np.std(act)))
print('F beta mean '+str(np.mean(fbe))+'+/-'+str(np.std(fbe)))
print('ROC AUC mean '+str(np.mean(roc))+'+/-'+str(np.std(roc)))
print('Ave Prec Score mean '+str(np.mean(avp))+'+/-'+str(np.std(avp)))
# Out:
# acc thresholded mean 0.9539874076843262+/-0.001325916218696785
# F beta mean 0.634507155418396+/-0.016767750445305662
# ROC AUC mean 0.9380262759158541+/-0.0035260055664953324
# Ave Prec Score mean 0.836872561870513+/-0.009526050914964342

# %%
def get_y_pred(y_prob, thresh):
    return (y_prob>thresh)

# %%
preds = get_y_pred(probs, thresh)

# %%
y_preds, y_true = learn.get_preds(ds_type=DatasetType.Valid)

# %%
[[p for p in pred if p > thresh] for pred in y_preds]
# Out:
# [[tensor(0.9991), tensor(0.9990), tensor(0.9983)],
#  [tensor(1.0000), tensor(0.9998), tensor(0.9999)],
#  [tensor(0.9999), tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9975)],
#  [tensor(1.0000), tensor(1.0000), tensor(0.9999)],
#  [tensor(1.0000)],
#  [],
#  [tensor(0.9945), tensor(0.9937), tensor(0.9940)],
#  [],
#  [tensor(0.7228)],
#  [tensor(0.9964)],
#  [tensor(0.9217)],
#  [tensor(0.9999), tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9999), tensor(0.9997), tensor(0.9991)],
#  [tensor(0.9986)],
#  [tensor(0.9998)],
#  [],
#  [],
#  [tensor(0.9189), tensor(0.9403), tensor(0.9749)],
#  [tensor(0.9951), tensor(0.9989)],
#  [tensor(0.9916)],
#  [tensor(1.0000)],
#  [tensor(0.7858)],
#  [tensor(0.9993), tensor(0.8638)],
#  [tensor(1.0000), tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000), tensor(1.), tensor(1.)],
#  [tensor(1.0000), tensor(1.0000), tensor(1.0000)],
#  [],
#  [tensor(1.0000), tensor(1.0000), tensor(0.9999)],
#  [tensor(0.9980), tensor(0.7575)],
#  [tensor(1.0000), tensor(1.0000), tensor(0.9998)],
#  [tensor(1.0000), tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9997), tensor(0.9996), tensor(0.9965)],
#  [tensor(1.0000), tensor(0.9999), tensor(1.0000)],
#  [tensor(0.9608), tensor(0.7251)],
#  [tensor(0.5259)],
#  [tensor(1.0000), tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9998), tensor(0.9997)],
#  [tensor(0.7789), tensor(0.9972), tensor(0.7861), tensor(0.8347)],
#  [tensor(0.9989)],
#  [],
#  [tensor(0.9912)],
#  [tensor(0.9998), tensor(0.9138)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9995), tensor(0.9996)],
#  [tensor(0.9999), tensor(1.0000)],
#  [],
#  [tensor(0.9996)],
#  [tensor(0.9290)],
#  [tensor(0.7886)],
#  [tensor(0.9981), tensor(0.7744)],
#  [tensor(0.9984)],
#  [tensor(0.9535)],
#  [tensor(0.9863)],
#  [tensor(0.9514)],
#  [tensor(1.0000), tensor(0.9996)],
#  [tensor(0.9957), tensor(0.9989)],
#  [tensor(0.9968)],
#  [tensor(1.0000), tensor(0.9999)],
#  [tensor(0.9870)],
#  [tensor(0.9999)],
#  [],
#  [tensor(0.9361)],
#  [tensor(0.9989)],
#  [tensor(0.9566), tensor(0.5649)],
#  [tensor(1.0000), tensor(0.9928)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9318), tensor(0.9495)],
#  [tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9153), tensor(0.7087)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9981)],
#  [tensor(1.0000)],
#  [tensor(0.8784)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9998), tensor(1.0000)],
#  [tensor(0.9993), tensor(0.9983)],
#  [tensor(0.9966)],
#  [tensor(0.9566)],
#  [tensor(0.9905)],
#  [tensor(0.9473)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9590), tensor(0.5561)],
#  [tensor(0.9763)],
#  [tensor(0.9909)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9845), tensor(0.9886)],
#  [tensor(0.9971)],
#  [tensor(0.6389)],
#  [],
#  [],
#  [tensor(0.9993)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.8750)],
#  [tensor(0.9549)],
#  [tensor(0.9999), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9813), tensor(0.9999)],
#  [tensor(0.9998), tensor(0.9993)],
#  [tensor(0.9999), tensor(1.0000)],
#  [tensor(0.9991), tensor(0.9876)],
#  [tensor(0.9990), tensor(0.9943)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9989), tensor(0.9912)],
#  [tensor(0.9994), tensor(1.0000)],
#  [tensor(0.9990), tensor(0.9891)],
#  [tensor(0.9995), tensor(1.0000)],
#  [tensor(0.9992), tensor(1.)],
#  [tensor(0.9999)],
#  [tensor(0.9995), tensor(1.0000)],
#  [tensor(0.9997), tensor(0.9998)],
#  [tensor(0.6951), tensor(0.9818)],
#  [tensor(1.0000), tensor(1.)],
#  [tensor(0.9998), tensor(1.0000)],
#  [tensor(0.7930)],
#  [],
#  [tensor(0.9983), tensor(0.9981)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9344)],
#  [tensor(1.0000), tensor(0.9605)],
#  [tensor(1.0000), tensor(1.)],
#  [tensor(1.0000), tensor(1.)],
#  [tensor(1.0000), tensor(0.9999)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000), tensor(1.)],
#  [tensor(1.0000), tensor(1.0000)],
#  [],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9998)],
#  [tensor(0.9999)],
#  [tensor(0.9909)],
#  [tensor(0.9533), tensor(0.9980)],
#  [tensor(0.9999), tensor(0.9999)],
#  [tensor(0.8974), tensor(0.5579)],
#  [tensor(1.0000), tensor(0.9839)],
#  [tensor(0.6010)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9715)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.5925), tensor(0.9523)],
#  [tensor(0.9961), tensor(0.9995)],
#  [tensor(0.9999), tensor(0.8824)],
#  [tensor(1.0000)],
#  [tensor(1.0000), tensor(0.9999)],
#  [],
#  [tensor(0.7886), tensor(0.8214)],
#  [],
#  [tensor(0.9999), tensor(1.0000)],
#  [],
#  [tensor(0.9998), tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9996), tensor(0.9157)],
#  [tensor(0.8056)],
#  [tensor(0.9597), tensor(0.9778)],
#  [tensor(0.9990)],
#  [tensor(0.9999)],
#  [],
#  [tensor(0.9999), tensor(0.9986)],
#  [tensor(0.9333)],
#  [tensor(0.9999), tensor(0.9977)],
#  [tensor(0.9943)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9999), tensor(0.9956)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9996), tensor(0.8760)],
#  [tensor(1.), tensor(0.8777)],
#  [tensor(1.0000), tensor(0.9999)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000), tensor(1.)],
#  [tensor(0.9999), tensor(0.9998)],
#  [tensor(1.0000), tensor(0.9994)],
#  [],
#  [tensor(1.0000), tensor(1.)],
#  [tensor(0.9998), tensor(0.9976)],
#  [tensor(1.0000), tensor(1.0000)],
#  [],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(0.9997)],
#  [tensor(0.9997), tensor(0.9997)],
#  [tensor(1.0000), tensor(0.9999)],
#  [tensor(1.0000), tensor(0.9998)],
#  [tensor(0.9999), tensor(0.9991)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9995), tensor(0.9995)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.), tensor(1.0000)],
#  [tensor(0.8803), tensor(0.9717)],
#  [],
#  [tensor(1.0000), tensor(0.8871)],
#  [tensor(0.5795)],
#  [tensor(0.9944)],
#  [tensor(0.7993)],
#  [tensor(1.)],
#  [tensor(0.9553)],
#  [tensor(0.8749)],
#  [tensor(0.7403)],
#  [tensor(0.6587)],
#  [tensor(0.9985), tensor(0.9981)],
#  [tensor(0.9938)],
#  [tensor(0.6257)],
#  [tensor(0.9331)],
#  [tensor(0.9998)],
#  [tensor(1.0000)],
#  [tensor(0.9505), tensor(0.5032)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.8421)],
#  [tensor(1.0000)],
#  [tensor(0.9824)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.), tensor(1.0000)],
#  [tensor(1.), tensor(1.0000)],
#  [tensor(1.0000), tensor(0.9773)],
#  [tensor(0.6047)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9992)],
#  [tensor(1.), tensor(1.0000)],
#  [tensor(0.9999), tensor(0.9997)],
#  [tensor(1.), tensor(1.0000)],
#  [tensor(0.9999), tensor(0.9999)],
#  [tensor(0.9997), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.), tensor(1.)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.)],
#  [tensor(0.9986), tensor(0.9998)],
#  [tensor(1.), tensor(1.)],
#  [tensor(1.0000), tensor(0.9998)],
#  [tensor(0.9998), tensor(1.0000)],
#  [tensor(0.9988), tensor(0.9999)],
#  [tensor(0.9984), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9753), tensor(0.8869)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9983), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.), tensor(1.0000)],
#  [tensor(0.9994), tensor(0.9031)],
#  [tensor(1.0000), tensor(0.9999)],
#  [tensor(1.), tensor(1.0000)],
#  [tensor(0.9999), tensor(0.9992)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9999), tensor(0.9997)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(0.9998)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.), tensor(1.)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.0000), tensor(0.9998)],
#  [tensor(0.9995), tensor(1.0000)],
#  [tensor(0.5912)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.), tensor(1.0000)],
#  [tensor(1.0000), tensor(1.0000)],
#  [tensor(1.), tensor(1.)],
#  [],
#  [tensor(0.9983), tensor(0.9998)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9994)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(0.9986)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9932)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(1.)],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9652)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.8195), tensor(0.8382)],
#  [tensor(0.9999)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9939)],
#  [tensor(1.)],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.8947)],
#  [],
#  [tensor(0.6669)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9997)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.7997)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9994)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9726)],
#  [tensor(0.9995)],
#  [tensor(1.0000)],
#  [tensor(0.9920)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(0.9981)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(0.9998)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(0.9879)],
#  [tensor(0.5216)],
#  [tensor(1.0000)],
#  [tensor(0.7891)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(0.8743)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9999)],
#  [tensor(0.9946)],
#  [tensor(1.0000)],
#  [tensor(0.8417)],
#  [tensor(0.9937)],
#  [tensor(0.7361)],
#  [tensor(0.9990)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9976)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.8346)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9994), tensor(0.9914)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.)],
#  [tensor(0.9998)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9997)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9984)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(0.8604), tensor(0.8514)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.7178)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9995)],
#  [tensor(0.9698)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9857), tensor(0.8945)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9997)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9890)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9976)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [],
#  [tensor(1.0000)],
#  [tensor(0.9281), tensor(0.6608)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.0000)],
#  [tensor(0.8255)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9923), tensor(0.5430)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.5468)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9910)],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9997)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9909)],
#  [tensor(1.0000)],
#  [tensor(0.8306)],
#  [tensor(0.9990)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(1.)],
#  [tensor(0.8755)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9999)],
#  [tensor(1.)],
#  [tensor(0.9969)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9980)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9998)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9983)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.7649)],
#  [tensor(1.0000)],
#  [tensor(0.9807)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000), tensor(0.9703)],
#  [tensor(0.9929)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9899)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [],
#  [tensor(0.9722)],
#  [tensor(0.8792), tensor(0.8540)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.6334)],
#  [tensor(0.9969)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9997)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9992), tensor(0.9996)],
#  [tensor(1.0000)],
#  [tensor(0.9186), tensor(0.9700)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9007)],
#  [tensor(1.0000)],
#  [],
#  [tensor(0.9667)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9934)],
#  [tensor(0.9806)],
#  [tensor(0.9997)],
#  [tensor(0.9983)],
#  [tensor(0.9997)],
#  [tensor(1.)],
#  [tensor(0.9999)],
#  [tensor(0.9788)],
#  [tensor(1.)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9995)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.7208)],
#  [tensor(0.9998)],
#  [tensor(0.9978)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(0.9999)],
#  [tensor(0.9999)],
#  [tensor(0.8647), tensor(0.6379)],
#  [tensor(1.0000)],
#  [tensor(0.9997)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9342)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9983)],
#  [tensor(1.0000)],
#  [tensor(0.9992)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9973)],
#  [tensor(1.0000)],
#  [tensor(0.9701)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.7136)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(0.9976)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(0.9077), tensor(0.5896)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9998)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9064)],
#  [tensor(0.9894)],
#  [tensor(0.9741)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9998), tensor(0.9997)],
#  [tensor(1.0000)],
#  [tensor(1.0000), tensor(0.9990)],
#  [tensor(1.)],
#  [],
#  [],
#  [tensor(1.0000)],
#  [],
#  [tensor(0.9998)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9998)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9990)],
#  [tensor(1.0000)],
#  [tensor(0.9854)],
#  [tensor(0.9999)],
#  [],
#  [tensor(1.0000)],
#  [tensor(0.9976)],
#  [tensor(0.8483)],
#  [],
#  [tensor(0.9509), tensor(0.7792)],
#  [tensor(0.6867)],
#  [tensor(0.8906)],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9976)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9792)],
#  [tensor(0.8661), tensor(0.5208)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(0.9991)],
#  [tensor(0.9992)],
#  [tensor(0.6089)],
#  [tensor(0.9997)],
#  [tensor(0.9988)],
#  [],
#  [tensor(0.9970)],
#  [tensor(1.0000)],
#  [tensor(0.9990)],
#  [tensor(0.9992), tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9986)],
#  [tensor(0.7404)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(0.9986)],
#  [tensor(1.0000)],
#  [tensor(0.9838)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.8278)],
#  [tensor(0.9901), tensor(0.9987)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [],
#  [tensor(0.9449)],
#  [tensor(1.0000)],
#  [tensor(0.9974)],
#  [tensor(0.9975)],
#  [tensor(0.9999)],
#  [tensor(0.9915)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9993)],
#  [tensor(1.0000)],
#  [tensor(0.9998)],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.6311), tensor(0.9993)],
#  [tensor(0.9988)],
#  [tensor(0.9893)],
#  [tensor(1.0000)],
#  [tensor(0.9521)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.8816)],
#  [tensor(0.9954), tensor(0.9996)],
#  [],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(0.9991)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.8394)],
#  [tensor(1.0000)],
#  [tensor(0.9994)],
#  [tensor(1.0000)],
#  [tensor(0.9681)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [],
#  [tensor(1.0000)],
#  [],
#  [],
#  [tensor(1.)],
#  [tensor(0.9996)],
#  [tensor(1.0000)],
#  [tensor(0.9149)],
#  [tensor(0.9964)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9990)],
#  [tensor(0.9997), tensor(0.9997)],
#  [tensor(0.9992)],
#  [tensor(0.9783)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9763)],
#  [tensor(1.0000)],
#  [tensor(0.9995)],
#  [tensor(0.9972)],
#  [tensor(1.0000)],
#  [tensor(0.9999)],
#  [tensor(1.0000)],
#  [tensor(1.0000)],
#  [tensor(0.9883)],
#  [tensor(1.0000)],
#  [tensor(1.)],
#  [tensor(0.9081), tensor(0.9590)],
#  [tensor(0.9886)],
#  [tensor(1.0000)],
#  ...]

# %%
learn.data.classes
# Out:
# ['antiinfective',
#  'antiinflammatory',
#  'antineoplastic',
#  'cardio',
#  'cns',
#  'dermatologic',
#  'gastrointestinal',
#  'hematologic',
#  'lipidregulating',
#  'reproductivecontrol',
#  'respiratorysystem',
#  'urological']

# %%
thresh = 0.5
labelled_preds = [' '.join([learn.data.classes[i] for i,p in enumerate(pred) if p > thresh]) for pred in y_preds]

# %%
with open('multiclass_validix5pred.csv', 'w') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerows(map(lambda x: [x], labelled_preds))

# %% [markdown]
# ## fin
